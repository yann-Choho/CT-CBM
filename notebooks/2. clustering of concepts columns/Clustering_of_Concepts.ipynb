# %% [markdown]
# # Clustering of concepts columns
#
# ---
# Goal of the notebook: .
#
# Inputs of the notebook:
# -  augmenetd dataframe with concepts
#
# Output of the notebook:
# - Cluster of concept in a json file

# %%
import sys
sys.path.append('../../run_experiments/')
sys.path.append('../../run_experiments/scripts')
sys.path.append('../../run_experiments/models')
sys.path.append('../../run_experiments/data')

import pandas as pd
import json

# %% [markdown]
# # 0. autoreload

# %%
#code for autoreload script associated with jupyter notebook
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # final clustering + stockage des cluster

# %%
from clustering import cluster_and_visualize_topics

model_name = 'bert-base-uncased'    # ou 'deberta-large'
dataset    = 'movies'               # 'movies' / 'agnews' / 'dbpedia' / 'medical'
annotation = 'C3M'       # 'C3M' ou 'our_annotation' ou 'combined_annotation'

aa = cluster_and_visualize_topics(
    model_name=model_name,
    dataset=dataset,
    annotation=annotation,
    min_cluster_size=2,
    random_state=42
)
# Out:
# /home/bhan/.conda/envs/good_env/lib/python3.12/site-packages/umap/umap_.py:1858: UserWarning: using precomputed metric; inverse_transform will be unavailable
#   warn("using precomputed metric; inverse_transform will be unavailable")
# /home/bhan/.conda/envs/good_env/lib/python3.12/site-packages/umap/umap_.py:1945: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(f"n_jobs value {self.n_jobs} overridden to 1 by setting random_state. Use no seed for parallelism.")
# Dictionnaire Stratégie 1 (noise réassigné) :
# Cluster 0 : ['dummy_focus on suspense', 'dummy_fear', 'dummy_threat to the protagonist', 'dummy_characters facing terrifying situations', 'dummy_dark tone', 'dummy_suspenseful tone', 'dummy_unsettling tone', 'dummy_fear of the unknown', 'dummy_mortality theme', 'dummy_fragility of life theme', 'dummy_gore', 'dummy_psychological terror', 'dummy_rugged characters', 'dummy_gritty tone', 'dummy_struggle for survival']
#
# ...

# %%
from clustering import cluster_and_visualize_topics

model_name = 'bert-base-uncased'    # ou 'deberta-large'
dataset    = 'movies'               # 'movies' / 'agnews' / 'dbpedia' / 'medical'
annotation = 'C3M'       # 'C3M' ou 'our_annotation' ou 'combined_annotation'

aa = cluster_and_visualize_topics(
    model_name=model_name,
    dataset=dataset,
    annotation=annotation,
    min_cluster_size=2,
    random_state=42
)
